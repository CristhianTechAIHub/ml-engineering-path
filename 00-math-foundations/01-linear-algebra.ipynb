# %% [markdown]
# # dot product
# The dot product is and operation that we use to know: how many near is the vector A to the vector B?
# $$\vec{A} \cdot \vec{B} = |A| |B| \cos(\theta)$$

# %%
A = [1,1]
B = [2,2]
C = [1,-1]
