# %% [markdown]
# # California Housing Prices
# We'll to fit a model to predict house prices in California using the 1990 census.

# %% [markdown]
# First, we should analizy the problem and discover the core of the problem. In this case, the main problem is people that try to predict prices are using tools that make get them erro up to 30%. In this case, training model is useful because model can have a
